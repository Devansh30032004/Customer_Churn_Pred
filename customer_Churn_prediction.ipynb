# %% [markdown]
# <a href="https://colab.research.google.com/github/Devansh30032004/Customer_Churn_Pred/blob/main/customer_Churn_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Customer Churn Prediction Model using Artificial Neural Network (ANN)**

# %% [markdown]
# Loading Required Packages and Libraries

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt

# %% [markdown]
# Dataset

# %%
df = pd.read_csv('customer_churn_dataset-testing-master.csv')

# %%
df.sample(5)
# Out:
#        CustomerID  Age  Gender  Tenure  Usage Frequency  Support Calls  \
# 59683       59684   37    Male      52               12              6
# 5789         5790   64  Female      58                1              6
# 59481       59482   54    Male       6                5              6
# 11925       11926   54    Male      54               16              6
# 53407       53408   38  Female      54               24              7
#
#        Payment Delay Subscription Type Contract Length  Total Spend  \
# 59683             26           Premium       Quarterly          253
# 5789              19           Premium       Quarterly          530
# 59481              4             Basic         Monthly          534
# 11925             19          Standard          Annual          399
# 53407             19             Basic         Monthly          452
#
#        Last Interaction  Churn
# 59683                22      1
# 5789                  3      1
# 59481                26      1
# 11925                 5      1
# 53407                13      1

# %% [markdown]
# Preprocessing of Dataset

# %%
df = df.drop('CustomerID', axis=1)

# %%
df.sample(5)
# Out:
#        Age  Gender  Tenure  Usage Frequency  Support Calls  Payment Delay  \
# 1022    65    Male      12                9              4             25
# 28066   52  Female      44                5              7             19
# 58169   20    Male      48               30              5             23
# 11891   24    Male      55                9              6             24
# 48619   59    Male      12                4             10             22
#
#       Subscription Type Contract Length  Total Spend  Last Interaction  Churn
# 1022            Premium         Monthly          779                12      0
# 28066           Premium       Quarterly          146                28      1
# 58169          Standard       Quarterly          226                15      1
# 11891             Basic         Monthly          578                30      1
# 48619          Standard          Annual          678                 3      1

# %%
df['Gender'].replace({'Male':1,'Female':0},inplace=True)
# Out:
# <ipython-input-30-f0312a8615ea>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Gender'].replace({'Male':1,'Female':0},inplace=True)
# <ipython-input-30-f0312a8615ea>:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Gender'].replace({'Male':1,'Female':0},inplace=True)

# %%
df.sample(5)
# Out:
#        Age  Gender  Tenure  Usage Frequency  Support Calls  Payment Delay  \
# 46085   49       1      47               20              9             24
# 30399   37       1      13               22              3              0
# 29376   46       0      12               12              7             18
# 62978   31       1      43               20              9             17
# 15474   36       0      16                5              9             27
#
#       Subscription Type Contract Length  Total Spend  Last Interaction  Churn
# 46085           Premium         Monthly          436                19      1
# 30399           Premium         Monthly          542                 4      0
# 29376           Premium       Quarterly          941                19      0
# 62978             Basic       Quarterly          252                13      1
# 15474          Standard          Annual          516                21      0

# %%
def print_unique_col_values(df):
    """
    Prints the unique values for each column in a Pandas DataFrame.

    Args:
        df: The Pandas DataFrame.
    """
    for column in df.columns:
        print(f"Unique values for '{column}': {df[column].unique()}")

print_unique_col_values(df) # Calling the function after defining it
# Out:
# Unique values for 'Age': [22 41 47 35 53 30 54 36 65 46 56 31 42 59 29 45 62 48 55 64 25 44 28 34
#  24 27 61 57 37 51 18 23 60 40 26 52 43 19 58 33 20 39 32 38 21 63 49 50]
# Unique values for 'Gender': [0 1]
# Unique values for 'Tenure': [25 28 27  9 58 41 37 36 20  8 42 13  2 46 21  1 54 40 39 50 59 60 44 23
#  26 31 30 51 45 19 14 24 15 47  3 17 22 57 34 29 33 35 56  5 55 48  6 32
#  16 10  7 43 52 53 38  4 11 18 49 12]
# Unique values for 'Usage Frequency': [14 28 10 12 24 15 11  5  4 27 23  7 17  3 30  2 19 20 18  8  6 21 26 16
#  25 13 29  9 22  1]
# Unique values for 'Support Calls': [ 4  7  2  5  9 10  0  6  1  3  8]
# Unique values for 'Payment Delay': [27 13 29 17  2 10 28 18  8 23 21 14 25  3  6 15  1  9 30  4  0 11 16  7
#  24 22 12 26 20 19  5]
# Unique values for 'Subscription Type': ['Basic' 'Standard' 'Premium']
# Unique values for 'Contract Length': ['Monthly' 'Annual' 'Quarterly']
# Unique values for 'Total Spend': [ 598  584  757  232  533  500  574  323  687  995  526  187  758  438
#   663  677  636  127  396  202  925  463  449  373  460  166  615  696
#   678  792  812  156  611  943  329  493  384  515  820 1000  405  879
#   771  600  825  231  259  244  705  136  843  402  919  699  733  563
#   448  172  933  576  657  731  665  546  579  599  554  986  844  668
#   867  471  628  761  372  213  996  403  468  368  759  966  784  332
#   364  209  428  347  418  322  920  894  570  632  442  969  719  941
#   218  225  345  769  717  199  821  900  175  317  779  635  524  382
#   990  532  377  486  640  104  392  255  237  555  444  630  664  186
#   978  254  123  921  335  803  888  712  257  355  201  133  910  419
#   115  121  736  934  119  994  411  817  200  837  164  413  423  235
#   862  775  581  796  354  946  838  150  716  912  350  973  683  561
#   203  538  720  588  656  261  447  527  833  715  239  224  566  295
#   890  258  371  312  749  140  960  854  344  841  866  212  650  505
#   909  298  725  126  393  722  654  805  230  984  849  408  826  302
#   846  205  131  426  309  313  889  799  828  481  207  366  153  300
#   662  388  874  971  689  280  506  690  514  885  644  278  466  953
#   465  292  940  741  380  501  407  101  226  337  163  987  487  863
#   415  607  592  256  603  721  173  845  210  802  305  808  464  197
#   646  800  672  666  525  404  951  285  476  681  823  582  977  550
#   169  474  446  641  647  707  918  704  519  296  718  141  928  621
#   999  706  593  130  107  431  503  795  124  420  982  421  899  686
#   288  321  651  924  814  265  425  872  693  738  839  149  870  619
#   959  763  642  328  494  927  233  968  534  238  190  653  536  406
#   412  165  272  271  535  675  790  548  590  776  383  360  676  948
#   291  907  865  346  158  307  788  583  848  228  168  284  880  992
#   336  562  521  409  751  191  649  445  489  362  612  183  735  804
#   318  109  457  755  399  543  441  314  523  752  440  478  625  770
#   851  389  152  439  831  745  974  956  857  648  182  913  891  569
#   970  155  976  780  936  482  993  334  293  701  801  206  125  748
#   512  710  580  634  724  685  760  282  905  192  400  289  330  553
#   507  113  379  577  267  287  495  416  196  470  618  245  198  962
#   586  363  475  338  947  935  221  652  747  559  188  742  520  903
#   181  908  859  858  659  955  591  174  111  369  601  861  306  855
#   340  247  726  756  132  608  873  311  997  882  589  853  884  462
#   702  248  483  827  496  374  106  824  610  211  184  339  473  937
#   727  467  573  349  981  564  274  605  606  791  980  299  714  401
#   988  660  537  622  578  358  793  850  961  963  361  571  219  679
#   429  942  376  216  509  436  772  251  222  597  122  547  629  430
#   391  454  270  764  778  631  835  737  499  229  684  682  931  572
#   938  798  840  822  939  297  435  138  528  204  154  326  542  777
#   806  540  461  914  410  433  906  551  370  497  964  189  842  268
#   915  455  767  479  159  732  674  522  450  281  856  351  492  740
#   139  531  558  277  422  568  623  813  179  451  147  930  797  768
#   691  162  658  477  783  375  819  144  729  972  680  240  273  560
#   266  253  234  194  185  215  498  398  617  604  502  711  834  688
#   739  898  892  263  116  151  698  645  161  923  989  949  356  703
#   331  157  627  178  432  952  958  595  488  985  260  667  945  249
#   904  517  639  876  353  148  177  397  766  893  264  304  227  807
#   269  452  386  504  786  746  348  832  552  881  490  241  385  637
#   883  950  609  868  142  530  670  669  170  728  878  661  193  753
#   134  129  310  734  830  424  787  480  290  809  897  975  944  875
#   518  575  587  565  491  545  143  508  308  246  544  387  252  394
#   275  195  118  303  979  108  887  283  929  117  926  965  596  120
#   341  782  103  324  390  869  998  378  932  357  671  774  250  316
#   513  794  105  811  708  860  816  743  847  815  516  135  785  352
#   750  102  484  437  886  744  171  852  223  643  836  567  294  697
#   638  773  319  114  236  700  585  276  694  301  208  762  325  616
#   485  160  417  243  818  810  220  365  967  594  176  709  145  327
#   146  713  829  510  613  456  626  367  434  541  472  655  917  414
#   359  765  556  864  214  395  620  453  901  320  286  279  333  557
#   242  624  443  458  692  877  781  217  896  167  789  381  469  895
#   180  871  673  602  954  695  911  110  128  427  112  262  902  614
#   983  137  922  343  511  342  754  723  991  315  539  730  633  100
#   549  529  916  459  957]
# Unique values for 'Last Interaction': [ 9 20 21 18 29 14 16  8 10  3  1 24 30 15 25 22 13 26 12  4 27  6 17 19
#   5  2 11  7 28 23]
# Unique values for 'Churn': [1 0]

# %% [markdown]
# Usage of One Hot Encoding for Categorical Columns

# %%
subscription_type_dummies = pd.get_dummies(df['Subscription Type'], prefix='Subscription')
df = pd.concat([df, subscription_type_dummies], axis=1)
df = df.drop('Subscription Type', axis=1)

# %%
df.dtypes
# Out:
# Age                       int64
# Gender                    int64
# Tenure                    int64
# Usage Frequency           int64
# Support Calls             int64
# Payment Delay             int64
# Contract Length          object
# Total Spend               int64
# Last Interaction          int64
# Churn                     int64
# Subscription_Basic         bool
# Subscription_Premium       bool
# Subscription_Standard      bool
# dtype: object

# %%
contract_length_dummies = pd.get_dummies(df['Contract Length'], prefix='Contract')
df = pd.concat([df, contract_length_dummies], axis=1)
df = df.drop('Contract Length', axis=1)
df.dtypes
# Out:
# Age                      int64
# Gender                   int64
# Tenure                   int64
# Usage Frequency          int64
# Support Calls            int64
# Payment Delay            int64
# Total Spend              int64
# Last Interaction         int64
# Churn                    int64
# Subscription_Basic        bool
# Subscription_Premium      bool
# Subscription_Standard     bool
# Contract_Annual           bool
# Contract_Monthly          bool
# Contract_Quarterly        bool
# dtype: object

# %%
df.sample(3)
# Out:
#        Age  Gender  Tenure  Usage Frequency  Support Calls  Payment Delay  \
# 36970   50       1      33               29              3             26
# 22806   27       0       5                7              6             19
# 51794   28       1      39               24              7             22
#
#        Total Spend  Last Interaction  Churn  Subscription_Basic  \
# 36970          795                 9      0                True
# 22806          735                24      0                True
# 51794          656                28      1                True
#
#        Subscription_Premium  Subscription_Standard  Contract_Annual  \
# 36970                 False                  False            False
# 22806                 False                  False            False
# 51794                 False                  False            False
#
#        Contract_Monthly  Contract_Quarterly
# 36970              True               False
# 22806              True               False
# 51794              True               False

# %%
for col in ['Subscription_Basic', 'Subscription_Premium', 'Subscription_Standard','Contract_Annual','Contract_Monthly','Contract_Quarterly']:
    df[col] = df[col].replace({True: 1, False: 0})
# Out:
# <ipython-input-37-df4bfa7af78f>:4: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[col] = df[col].replace({True: 1, False: 0})

# %%
df.dtypes
# Out:
# Age                      int64
# Gender                   int64
# Tenure                   int64
# Usage Frequency          int64
# Support Calls            int64
# Payment Delay            int64
# Total Spend              int64
# Last Interaction         int64
# Churn                    int64
# Subscription_Basic       int64
# Subscription_Premium     int64
# Subscription_Standard    int64
# Contract_Annual          int64
# Contract_Monthly         int64
# Contract_Quarterly       int64
# dtype: object

# %%
df.sample(10)
# Out:
#        Age  Gender  Tenure  Usage Frequency  Support Calls  Payment Delay  \
# 41459   23       1      37                2              2             28
# 16211   55       1      12                6              4             21
# 14398   29       1       7               17             10             26
# 1898    40       0      49                3              4              0
# 18669   45       0      24               30              4             18
# 9140    35       0      18               27              8              7
# 19649   63       0      35               26              6             28
# 18230   62       0      34               18             10             19
# 4135    40       0      28                3              4             18
# 20369   38       0      33               15              4             25
#
#        Total Spend  Last Interaction  Churn  Subscription_Basic  \
# 41459          331                22      0                   0
# 16211          808                12      0                   1
# 14398          711                 5      0                   1
# 1898           825                17      0                   1
# 18669          670                17      0                   0
# 9140           274                29      0                   1
# 19649          244                 6      1                   0
# 18230          360                 8      1                   0
# 4135           452                 1      0                   1
# 20369          943                 2      0                   0
#
#        Subscription_Premium  Subscription_Standard  Contract_Annual  \
# 41459                     0                      1                1
# 16211                     0                      0                0
# 14398                     0                      0                0
# 1898                      0                      0                0
# 18669                     1                      0                1
# 9140                      0                      0                0
# 19649                     0                      1                1
# 18230                     1                      0                1
# 4135                      0                      0                0
# 20369                     1                      0                1
#
#        Contract_Monthly  Contract_Quarterly
# 41459                 0                   0
# 16211                 1                   0
# 14398                 1                   0
# 1898                  0                   1
# 18669                 0                   0
# 9140                  0                   1
# 19649                 0                   0
# 18230                 0                   0
# 4135                  0                   1
# 20369                 0                   0

# %% [markdown]
# Normalizing Columns onto scale of 0-1

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

# Select the columns to scale
columns_to_scale = ['Age', 'Tenure', 'Usage Frequency', 'Support Calls', 'Payment Delay', 'Total Spend', 'Last Interaction']

# Fit and transform the selected columns
df[columns_to_scale] = scaler.fit_transform(df[columns_to_scale])

# Display the scaled DataFrame (optional)
df.sample(10)
# Out:
#             Age  Gender    Tenure  Usage Frequency  Support Calls  \
# 45582  0.425532       0  0.305085         0.068966            0.5
# 60621  0.191489       1  0.915254         0.827586            0.6
# 50634  0.085106       0  0.322034         0.413793            0.3
# 51439  0.170213       0  0.661017         0.655172            0.4
# 3332   0.553191       1  0.779661         1.000000            0.9
# 6094   0.638298       0  0.152542         0.344828            0.4
# 16192  0.574468       0  0.593220         0.517241            0.6
# 15918  0.425532       0  0.067797         0.448276            1.0
# 16253  0.340426       1  0.186441         0.586207            0.9
# 8000   0.531915       0  0.372881         0.275862            0.7
#
#        Payment Delay  Total Spend  Last Interaction  Churn  \
# 45582       0.100000     0.040000          0.275862      0
# 60621       0.933333     0.888889          0.965517      1
# 50634       0.866667     0.456667          1.000000      1
# 51439       0.766667     0.123333          0.586207      1
# 3332        0.833333     0.432222          0.068966      1
# 6094        0.466667     0.865556          0.724138      0
# 16192       0.433333     0.640000          0.965517      0
# 15918       0.733333     0.331111          0.310345      1
# 16253       0.200000     0.128889          0.172414      0
# 8000        0.766667     0.763333          0.413793      1
#
#        Subscription_Basic  Subscription_Premium  Subscription_Standard  \
# 45582                   1                     0                      0
# 60621                   1                     0                      0
# 50634                   1                     0                      0
# 51439                   0                     1                      0
# 3332                    1                     0                      0
# 6094                    1                     0                      0
# 16192                   0                     0                      1
# 15918                   0                     1                      0
# 16253                   1                     0                      0
# 8000                    0                     0                      1
#
#        Contract_Annual  Contract_Monthly  Contract_Quarterly
# 45582                0                 0                   1
# 60621                0                 0                   1
# 50634                0                 1                   0
# 51439                0                 1                   0
# 3332                 0                 1                   0
# 6094                 0                 0                   1
# 16192                0                 1                   0
# 15918                0                 1                   0
# 16253                0                 1                   0
# 8000                 0                 1                   0

# %%
df.dtypes
# Out:
# Age                      float64
# Gender                     int64
# Tenure                   float64
# Usage Frequency          float64
# Support Calls            float64
# Payment Delay            float64
# Total Spend              float64
# Last Interaction         float64
# Churn                      int64
# Subscription_Basic         int64
# Subscription_Premium       int64
# Subscription_Standard      int64
# Contract_Annual            int64
# Contract_Monthly           int64
# Contract_Quarterly         int64
# dtype: object

# %% [markdown]
# Spiltting Training and Testing Datasets

# %%
X = df.drop('Churn', axis=1)
Y = df['Churn']
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,Y,test_size=0.2,random_state=5)

# %%
X_train.shape
# Out:
# (51499, 14)

# %% [markdown]
# Defining Model using ANN

# %%
from tensorflow.keras import Sequential, layers

model = Sequential([
    layers.Dense(16, activation='relu', input_shape=(X_train.shape[1],)),
    layers.Dense(32, activation='relu'),
    layers.Dense(1, activation='sigmoid')
])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# Training Model

# %%
from tensorflow.keras import losses, optimizers, metrics

model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

model.fit(X_train, y_train, epochs=10)
# Out:
# Epoch 1/10
# 1610/1610 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9318 - loss: 0.1648
# Epoch 2/10
# 1610/1610 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9362 - loss: 0.1537
# Epoch 3/10
# 1610/1610 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9377 - loss: 0.1518
# Epoch 4/10
# 1610/1610 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9414 - loss: 0.1432
# Epoch 5/10
# 1610/1610 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9454 - loss: 0.1316
# Epoch 6/10
# 1610/1610 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9461 - loss: 0.1286
# Epoch 7/10
# 1610/1610 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9492 - loss: 0.1212
# Epoch 8/10
# 1610/1610 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.9517 - loss: 0.1156
# Epoch 9/10
# 1610/1610 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9547 - loss: 0.1089
# Epoch 10/10
# 1610/1610 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9589 - loss: 0.0997

# %% [markdown]
# Evaluation of Model on Test data

# %%
loss, accuracy = model.evaluate(X_test, y_test)
print(f"Loss: {loss}")
print(f"Accuracy: {accuracy}")
# Out:
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9567 - loss: 0.1046
# Loss: 0.10152489691972733
# Accuracy: 0.9589126110076904

# %% [markdown]
# Classification Report of Model

# %%
# prompt: classification report generation

from sklearn.metrics import classification_report

y_pred = model.predict(X_test)
y_pred = (y_pred > 0.5) # Convert probabilities to binary predictions

print(classification_report(y_test, y_pred))
# Out:
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
#               precision    recall  f1-score   support
#
#            0       0.95      0.97      0.96      6801
#            1       0.97      0.95      0.96      6074
#
#     accuracy                           0.96     12875
#    macro avg       0.96      0.96      0.96     12875
# weighted avg       0.96      0.96      0.96     12875

# %%
# prompt: plot train vs test accuracy & loss

# Assuming you have already trained the model as shown in the provided code.

# Get training history
history = model.fit(X_train, y_train, epochs=10, validation_data=(X_test, y_test))


# Plot training & validation accuracy values
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
# Out:
# Epoch 1/10
# 1610/1610 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9602 - loss: 0.0958 - val_accuracy: 0.9659 - val_loss: 0.0909
# Epoch 2/10
# 1610/1610 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9632 - loss: 0.0904 - val_accuracy: 0.9653 - val_loss: 0.0893
# Epoch 3/10
# 1610/1610 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9656 - loss: 0.0863 - val_accuracy: 0.9669 - val_loss: 0.0862
# Epoch 4/10
# 1610/1610 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.9674 - loss: 0.0810 - val_accuracy: 0.9679 - val_loss: 0.0844
# Epoch 5/10
# 1610/1610 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9673 - loss: 0.0817 - val_accuracy: 0.9686 - val_loss: 0.0775
# Epoch 6/10
# 1610/1610 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9689 - loss: 0.0765 - val_accuracy: 0.9704 - val_loss: 0.0748
# Epoch 7/10
# 1610/1610 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9702 - loss: 0.0728 - val_accuracy: 0.9717 - val_loss: 0.0737
# Epoch 8/10
# 1610/1610 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9712 - loss: 0.0712 - val_accuracy: 0.9695 - val_loss: 0.0733
# Epoch 9/10
# 1610/1610 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9724 - loss: 0.0675 - val_accuracy: 0.9706 - val_loss: 0.0723
# Epoch 10/10
# 1610/1610 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9717 - loss: 0.0693 - val_accuracy: 0.9719 - val_loss: 0.0711
